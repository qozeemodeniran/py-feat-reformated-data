# %%
from feat import Detector
from feat.utils.io import get_test_data_path
import os

detector = Detector()
test_data_dir = get_test_data_path()
test_video_path = os.path.join(test_data_dir, "Ana_legit.mp4") 
video_prediction = detector.detect_video("C:/Users/Public\Desktop/feat/F2_Ana/Ana_legit.mp4", skip_frames=10)
video_prediction.head()

video_prediction.shape

video_prediction.loc[0:2].plot_detections(faceboxes=False, add_titles=False)

axes = video_prediction.emotions.plot()

video_prediction.to_csv("C:/Users/Public\Desktop/feat/F2_Ana/Ana_legit.csv")
# Out:
# 100%|██████████| 48/48 [03:07<00:00,  3.91s/it]

# %%
from feat import Detector
from feat.utils.io import get_test_data_path
import os

detector = Detector()
test_data_dir = get_test_data_path()
test_video_path = os.path.join(test_data_dir, "Ana_phish.mp4") 
video_prediction = detector.detect_video("C:/Users/Public\Desktop/feat/F2_Ana/Ana_phish.mp4", skip_frames=10)
video_prediction.head()

video_prediction.shape

video_prediction.loc[0:2].plot_detections(faceboxes=False, add_titles=False)

axes = video_prediction.emotions.plot()

video_prediction.to_csv("C:/Users/Public\Desktop/feat/F2_Ana/Ana_phish.csv")
# Out:
# 100%|██████████| 196/196 [08:53<00:00,  2.72s/it]

# %%
from feat import Detector
from feat.utils.io import get_test_data_path
import os

detector = Detector()
test_data_dir = get_test_data_path()
test_video_path = os.path.join(test_data_dir, "Ana_spam.mp4") 
video_prediction = detector.detect_video("C:/Users/Public\Desktop/feat/F2_Ana/Ana_spam.mp4", skip_frames=10)
video_prediction.head()

video_prediction.shape

video_prediction.loc[0:2].plot_detections(faceboxes=False, add_titles=False)

axes = video_prediction.emotions.plot()

video_prediction.to_csv("C:/Users/Public\Desktop/feat/F2_Ana/Ana_spam.csv")
# Out:
# 100%|██████████| 69/69 [02:36<00:00,  2.27s/it]
