# %%
from feat import Detector
from feat.utils.io import get_test_data_path
import os

detector = Detector()
test_data_dir = get_test_data_path()
test_video_path = os.path.join(test_data_dir, "SPlegit.mp4") 
video_prediction = detector.detect_video("C:/Users/Public/Desktop/feat/M1_Sammy/SPlegit.mp4", skip_frames=10)
video_prediction.head()

video_prediction.shape

video_prediction.loc[0:2].plot_detections(faceboxes=False, add_titles=False)

axes = video_prediction.emotions.plot()

video_prediction.to_csv("C:/Users/Public/Desktop/feat/M1_Sammy/Sammy_Legit.csv")
# Out:
# 100%|██████████| 47/47 [01:46<00:00,  2.27s/it]

# %%
from feat import Detector
from feat.utils.io import get_test_data_path
import os

detector = Detector()
test_data_dir = get_test_data_path()
test_video_path = os.path.join(test_data_dir, "SPphish.mp4") 
video_prediction = detector.detect_video("C:/Users/Public/Desktop/feat/M1_Sammy/SPphish.mp4", skip_frames=10)
video_prediction.head()

video_prediction.shape

video_prediction.loc[0:2].plot_detections(faceboxes=False, add_titles=False)

axes = video_prediction.emotions.plot()

video_prediction.to_csv("C:/Users/Public/Desktop/feat/M1_Sammy/Sammy_Phish.csv")
# Out:
# 100%|██████████| 124/124 [04:55<00:00,  2.39s/it]

# %%
from feat import Detector
from feat.utils.io import get_test_data_path
import os

detector = Detector()
test_data_dir = get_test_data_path()
test_video_path = os.path.join(test_data_dir, "SPspam.mp4") 
video_prediction = detector.detect_video("C:/Users/Public/Desktop/feat/M1_Sammy/SPspam.mp4", skip_frames=10)
video_prediction.head()

video_prediction.shape

video_prediction.loc[0:2].plot_detections(faceboxes=False, add_titles=False)

axes = video_prediction.emotions.plot()

video_prediction.to_csv("C:/Users/Public/Desktop/feat/M1_Sammy/Sammy_Spam.csv")
# Out:
# 100%|██████████| 33/33 [01:18<00:00,  2.37s/it]
