# %%
from feat import Detector
from feat.utils.io import get_test_data_path
import os

detector = Detector()
test_data_dir = get_test_data_path()
test_video_path = os.path.join(test_data_dir, "JDlegit.mp4") 
video_prediction = detector.detect_video("C:/Users/Public/Desktop/feat/M2_JD/JDlegit.mp4", skip_frames=10)
video_prediction.head()

video_prediction.shape

video_prediction.loc[0:2].plot_detections(faceboxes=False, add_titles=False)

axes = video_prediction.emotions.plot()

video_prediction.to_csv("C:/Users/Public/Desktop/feat/M2_JD/JD_Legit.csv")
# Out:
# 100%|██████████| 28/28 [01:06<00:00,  2.37s/it]

# %%
from feat import Detector
from feat.utils.io import get_test_data_path
import os

detector = Detector()
test_data_dir = get_test_data_path()
test_video_path = os.path.join(test_data_dir, "JDphish.mp4") 
video_prediction = detector.detect_video("C:/Users/Public/Desktop/feat/M2_JD/JDphish.mp4", skip_frames=10)
video_prediction.head()

video_prediction.shape

video_prediction.loc[0:2].plot_detections(faceboxes=False, add_titles=False)

axes = video_prediction.emotions.plot()

video_prediction.to_csv("C:/Users/Public/Desktop/feat/M2_JD/JD_Phish.csv")
# Out:
# ...
# 100%|██████████| 128/128 [04:55<00:00,  2.31s/it]

# %%
from feat import Detector
from feat.utils.io import get_test_data_path
import os

detector = Detector()
test_data_dir = get_test_data_path()
test_video_path = os.path.join(test_data_dir, "JDspam.mp4") 
video_prediction = detector.detect_video("C:/Users/Public/Desktop/feat/M2_JD/JDspam.mp4", skip_frames=10)
video_prediction.head()

video_prediction.shape

video_prediction.loc[0:2].plot_detections(faceboxes=False, add_titles=False)

axes = video_prediction.emotions.plot()

video_prediction.to_csv("C:/Users/Public/Desktop/feat/M2_JD/JD_Spam.csv")
# Out:
# 100%|██████████| 37/37 [01:22<00:00,  2.22s/it]
